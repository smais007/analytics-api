# %%
import requests

path = "/api/events/qw"
base_url = "http://localhost:8002"

endpoint = f"{base_url}{path}"

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# False

# %%
if response.ok:
    data = response.json()
    print(data)
